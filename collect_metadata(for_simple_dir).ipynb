# %% [markdown]
# # GI-Tract Image Segmentation
#
# ## Data Preprocessing - For Simplified Directory (e.g. 2.5D Data)
#
# #### by Zhiyin (Steven) Lu

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %ls

# %%
import glob
import pandas as pd

# %%
# get scan and mask image information and organize into a dataframe
scan_dir = './data_simple_dir/scans/*.png'
mask_dir = './data_simple_dir/masks/*.npy'
save_dir = './data_simple_dir/data.csv'
save_debug_dir = './data_simple_dir/debug.csv'

# scan_dir = './2.5d_data/scans/*.npy' 
# mask_dir = './2.5d_data/masks/*.npy'
# save_dir = './2.5d_data/data.csv'
# save_debug_dir = './2.5d_data/masks/debug.csv'

scan_path = sorted(glob.glob(scan_dir))
mask_path = sorted(glob.glob(mask_dir))
data = pd.DataFrame(data={'scan_path': scan_path, 'mask_path': mask_path})

# extract information into separate columns
data['id'] = data.scan_path.map( lambda x: '_'.join(x.split('/')[-1].split('_')[:4]) )
data['case'] = data.id.map( lambda x: int(x.split('_')[0][4:]) )
data['day'] = data.id.map( lambda x: int(x.split('_')[1][3:]) )
data['slice'] = data.id.map( lambda x: int(x.split('_')[-1]) )
data['height'] = data.scan_path.map( lambda x: int(x.split('/')[-1].split('_')[-4]) )
data['width'] = data.scan_path.map( lambda x: int(x.split('/')[-1].split('_')[-3]) )

# get the segmentation information from train.csv and organize into a 'masks' dataframe
train_csv_dir = './data/train.csv'
train_csv = pd.read_csv(train_csv_dir)
train_csv.segmentation = train_csv.segmentation.fillna('')
train_csv['rle_len'] = train_csv.segmentation.map(len)

# group segmentation into lists and calculate the length of the segmentation list
seg = train_csv.groupby(['id'])['segmentation'].agg(list).to_frame()
rle_len = train_csv.groupby(['id'])['rle_len'].agg(sum).to_frame()

# merge and add segmentation list and rle_length to the 'mask_info' dataframe
mask_info = seg.merge(rle_len, on=['id'])
mask_info['empty'] = (mask_info['rle_len'] == 0)

# merge 'scans' and 'masks' into one dataframe based on IDs
data = data.merge(mask_info, on=['id'])

# Total: 38496
display(data)

data.to_csv(save_dir, index=False)
# Out:
#                                                scan_path  \
# 0      ./data_simple_dir/scans/case101_day20_slice_00...
# 1      ./data_simple_dir/scans/case101_day20_slice_00...
# 2      ./data_simple_dir/scans/case101_day20_slice_00...
# 3      ./data_simple_dir/scans/case101_day20_slice_00...
# 4      ./data_simple_dir/scans/case101_day20_slice_00...
# ...                                                  ...
# 38491  ./data_simple_dir/scans/case9_day22_slice_0140...
# 38492  ./data_simple_dir/scans/case9_day22_slice_0141...
# 38493  ./data_simple_dir/scans/case9_day22_slice_0142...
# 38494  ./data_simple_dir/scans/case9_day22_slice_0143...
# 38495  ./data_simple_dir/scans/case9_day22_slice_0144...
#
#                                                mask_path  \
# 0      ./data_simple_dir/masks/case101_day20_slice_00...
# 1      ./data_simple_dir/masks/case101_day20_slice_00...
# 2      ./data_simple_dir/masks/case101_day20_slice_00...
# 3      ./data_simple_dir/masks/case101_day20_slice_00...
# 4      ./data_simple_dir/masks/case101_day20_slice_00...
# ...                                                  ...
# 38491  ./data_simple_dir/masks/case9_day22_slice_0140...
# 38492  ./data_simple_dir/masks/case9_day22_slice_0141...
# 38493  ./data_simple_dir/masks/case9_day22_slice_0142...
# 38494  ./data_simple_dir/masks/case9_day22_slice_0143...
# 38495  ./data_simple_dir/masks/case9_day22_slice_0144...
#
#                              id  case  day  slice  height  width segmentation  \
# 0      case101_day20_slice_0001   101   20      1     266    266       [, , ]
# 1      case101_day20_slice_0002   101   20      2     266    266       [, , ]
# 2      case101_day20_slice_0003   101   20      3     266    266       [, , ]
# 3      case101_day20_slice_0004   101   20      4     266    266       [, , ]
# 4      case101_day20_slice_0005   101   20      5     266    266       [, , ]
# ...                         ...   ...  ...    ...     ...    ...          ...
# 38491    case9_day22_slice_0140     9   22    140     360    310       [, , ]
# 38492    case9_day22_slice_0141     9   22    141     360    310       [, , ]
# 38493    case9_day22_slice_0142     9   22    142     360    310       [, , ]
# 38494    case9_day22_slice_0143     9   22    143     360    310       [, , ]
# 38495    case9_day22_slice_0144     9   22    144     360    310       [, , ]
#
#        rle_len  empty
# 0            0   True
# 1            0   True
# 2            0   True
# 3            0   True
# 4            0   True
# ...        ...    ...
# 38491        0   True
# 38492        0   True
# 38493        0   True
# 38494        0   True
# 38495        0   True
#
# [38496 rows x 11 columns]

# %%
##### RANDOM SAMPLING TO GET A SMALL DATASET FOR DEBUG PURPOSE #####
debug = data.sample(n=20, random_state=1)

display(debug)

debug.to_csv(save_debug_dir, index=False)
# Out:
#                                                scan_path  \
# 16139  ./data_simple_dir/scans/case148_day20_slice_00...
# 16022  ./data_simple_dir/scans/case148_day0_slice_005...
# 23096  ./data_simple_dir/scans/case33_day21_slice_007...
# 27187  ./data_simple_dir/scans/case47_day0_slice_0004...
# 34168  ./data_simple_dir/scans/case7_day19_slice_0073...
# 13452  ./data_simple_dir/scans/case142_day16_slice_00...
# 36255  ./data_simple_dir/scans/case85_day29_slice_014...
# 13918  ./data_simple_dir/scans/case143_day23_slice_00...
# 17681  ./data_simple_dir/scans/case156_day10_slice_01...
# 20287  ./data_simple_dir/scans/case22_day0_slice_0144...
# 14659  ./data_simple_dir/scans/case145_day19_slice_00...
# 36447  ./data_simple_dir/scans/case88_day36_slice_004...
# 16632  ./data_simple_dir/scans/case149_day15_slice_00...
# 7020   ./data_simple_dir/scans/case123_day20_slice_01...
# 28242  ./data_simple_dir/scans/case54_day0_slice_0051...
# 12875  ./data_simple_dir/scans/case141_day13_slice_00...
# 19399  ./data_simple_dir/scans/case19_day14_slice_012...
# 15127  ./data_simple_dir/scans/case146_day24_slice_01...
# 32022  ./data_simple_dir/scans/case74_day0_slice_0087...
# 9160   ./data_simple_dir/scans/case130_day22_slice_01...
#
#                                                mask_path  \
# 16139  ./data_simple_dir/masks/case148_day20_slice_00...
# 16022  ./data_simple_dir/masks/case148_day0_slice_005...
# 23096  ./data_simple_dir/masks/case33_day21_slice_007...
# 27187  ./data_simple_dir/masks/case47_day0_slice_0004...
# 34168  ./data_simple_dir/masks/case7_day19_slice_0073...
# 13452  ./data_simple_dir/masks/case142_day16_slice_00...
# 36255  ./data_simple_dir/masks/case85_day29_slice_014...
# 13918  ./data_simple_dir/masks/case143_day23_slice_00...
# 17681  ./data_simple_dir/masks/case156_day10_slice_01...
# 20287  ./data_simple_dir/masks/case22_day0_slice_0144...
# 14659  ./data_simple_dir/masks/case145_day19_slice_00...
# 36447  ./data_simple_dir/masks/case88_day36_slice_004...
# 16632  ./data_simple_dir/masks/case149_day15_slice_00...
# 7020   ./data_simple_dir/masks/case123_day20_slice_01...
# 28242  ./data_simple_dir/masks/case54_day0_slice_0051...
# 12875  ./data_simple_dir/masks/case141_day13_slice_00...
# 19399  ./data_simple_dir/masks/case19_day14_slice_012...
# 15127  ./data_simple_dir/masks/case146_day24_slice_01...
# 32022  ./data_simple_dir/masks/case74_day0_slice_0087...
# 9160   ./data_simple_dir/masks/case130_day22_slice_01...
#
#                              id  case  day  slice  height  width  \
# 16139  case148_day20_slice_0028   148   20     28     360    310
# 16022   case148_day0_slice_0055   148    0     55     360    310
# 23096   case33_day21_slice_0073    33   21     73     266    266
# 27187    case47_day0_slice_0004    47    0      4     266    266
# 34168    case7_day19_slice_0073     7   19     73     266    266
# 13452  case142_day16_slice_0013   142   16     13     266    266
# 36255   case85_day29_slice_0144    85   29    144     360    310
# 13918  case143_day23_slice_0047   143   23     47     266    266
# 17681  case156_day10_slice_0130   156   10    130     266    266
# 20287    case22_day0_slice_0144    22    0    144     266    266
# 14659  case145_day19_slice_0068   145   19     68     360    310
# 36447   case88_day36_slice_0048    88   36     48     360    310
# 16632  case149_day15_slice_0089   149   15     89     266    266
# 7020   case123_day20_slice_0141   123   20    141     266    266
# 28242    case54_day0_slice_0051    54    0     51     266    266
# 12875  case141_day13_slice_0012   141   13     12     266    266
# 19399   case19_day14_slice_0120    19   14    120     360    310
# 15127  case146_day24_slice_0104   146   24    104     266    266
# 32022    case74_day0_slice_0087    74    0     87     266    266
# 9160   case130_day22_slice_0121   130   22    121     266    266
#
#                                             segmentation  rle_len  empty
# 16139                                             [, , ]        0   True
# 16022                                             [, , ]        0   True
# 23096  [, , 29459 5 29721 10 29982 16 30246 18 30510 ...      331  False
# 27187                                             [, , ]        0   True
# 34168  [, , 29692 5 29956 9 30221 11 30486 13 30751 1...      420  False
# 13452                                             [, , ]        0   True
# 36255                                             [, , ]        0   True
# 13918  [35819 8 36084 12 36349 15 36615 17 36881 17 3...      424  False
# 17681  [20067 4 20331 9 20348 11 20595 31 20860 33 21...     1310  False
# 20287                                             [, , ]        0   True
# 14659  [27609 1 27965 7 28324 10 28683 12 29043 12 29...     1347  False
# 36447                                             [, , ]        0   True
# 16632  [20600 5 20863 10 21125 15 21390 17 21623 1 21...     1707  False
# 7020                                              [, , ]        0   True
# 28242  [27336 6 27346 2 27600 17 27865 19 28130 21 28...     1305  False
# 12875                                             [, , ]        0   True
# 19399                                             [, , ]        0   True
# 15127  [24018 8 24282 11 24547 13 24813 14 25078 16 2...     1384  False
# 32022  [22514 3 22778 7 23043 9 23308 11 23574 12 238...      781  False
# 9160                                              [, , ]        0   True
